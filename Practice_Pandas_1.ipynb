# %% [raw]
# Pandas is a library where we can deal with different kind of file like csv,excel.Pandas is a kind of library which will be able to read,write,filter and manipulation of these files

# %%
Suppose we can

# %%
d="""{  "name" : "Vandana Kumari",
"email_id" :"vandih@1234",
"tech":["ML","DL","CV"],
"platform":["techneuron","kidsneuron","ineuron"]
}
"""

# %%
type(d)
# Out:
# str

# %%
import pandas as pd

# %%
import json

# %%
result=json.loads(d)

# %%
type(result)
# Out:
# dict

# %%
pd.DataFrame(result)
# Out:
#              name     email_id tech    platform
# 0  Vandana Kumari  vandih@1234   ML  techneuron
# 1  Vandana Kumari  vandih@1234   DL  kidsneuron
# 2  Vandana Kumari  vandih@1234   CV     ineuron

# %%
#It is giving error here as name datatype is string as string cannot be converted into dataframe
pd.DataFrame(result["name"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-6f8165975971> in <module>
# ----> 1 pd.DataFrame(result["name"])
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     507                 )
#     508             else:
# --> 509                 raise ValueError("DataFrame constructor not properly called!")
#     510
#     511         NDFrame.__init__(self, mgr, fastpath=True)
#
# ValueError: DataFrame constructor not properly called!

# %%
result["name"]
# Out:
# 'Vandana Kumari'

# %%
result["tech"]
# Out:
# ['ML', 'DL', 'CV']

# %%
#List can be converted into  dataframe format
pd.DataFrame(result["tech"])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
#here is one more data

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50224',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50224/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50224/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50224/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/50224',
#   'id': 1493338525,
#   'node_id': 'PR_kwDOAA0YD85FRWzJ',
#   'number': 50224,
#   'title': 'BUG: DataFrame reductions with object dtype and axis=1',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
# ...

# %%
#how many unique dictionaries are available.30 unique dictionaries are available
len(data1)
# Out:
# 30

# %%
#from one single dictionary how can we extract one single user id
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50224',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50224/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50224/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/50224/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/50224',
#  'id': 1493338525,
#  'node_id': 'PR_kwDOAA0YD85FRWzJ',
#  'number': 50224,
#  'title': 'BUG: DataFrame reductions with object dtype and axis=1',
#  'user': {'login': 'rhshadrach',
#   'id': 45562402,
#   'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rhshadrach',
#   'html_url': 'https://github.com/rhshadrach',
#   'followers_url': 'https://api.github.com/users/rhshadrach/followers',
# ...

# %%
data1[0]["user"]["id"]
# Out:
# 45562402

# %%
#how can we extract all the userid from 30 dictionaries by using for loop
for i in range(len(data1)):
    print(data1[i]["user"]["id"])
# Out:
# 45562402
# 60926009
# 8078968
# 66137619
# 8078968
# 8078968
# 49123398
# 49123398
# 8078968
# 39504233
# 33491632
# 33491632
# 33491632
# 56310501
# 33455644
# 51368516
# 64493622
# 77875500
# 60926009
# 26364415
# 59670951
# 37260065
# 8066014
# 59670951
# 28800819
# 51368516
# 35031631
# 8066014
# 55934929
# 26364415
